# %%
import pandas as pd

# %%
irp = pd.read_csv("/Users/marcdelabarrera/Downloads/irp_from_fig_dotdecimal.csv",sep=';')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
irp.plot(x="date",y="irp_5", ax=ax)
irp.plot(x="date",y="irp_10", ax=ax)
# Out:
# <Axes: xlabel='date'>
