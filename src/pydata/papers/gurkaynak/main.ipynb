# %%
import pandas as pd
from main import read_data

# %%
DATE_FROM = "1985-01-01"
DATE_TO = "2020-01-01"
df = read_data(DATE_FROM, DATE_TO)

# %%
date = "2000-02-01"
df.loc[date, [col for col in df.columns if col.startswith("SVENY")]].plot()
# Out:
# <Axes: >

# %%
df["SVENY01"].plot()
df["SVENY05"].plot()
df["SVENY10"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
(df["SVENY05"]-df["SVENY01"]).plot()
(df["SVENY10"]-df["SVENY01"]).plot()
# Out:
# <Axes: xlabel='date'>

# %%
(df["SVENY05"]-df["SVENY01"]).mean(), (df["SVENY10"]-df["SVENY01"]).mean()
# Out:
# (np.float64(0.8977572011439722), np.float64(1.5658096971970223))

# %%
pd.read_csv("feds200628.csv", skiprows = 8)
# Out:
#              Date     BETA0     BETA1     BETA2      BETA3  SVEN1F01  \
# 0      1961-06-14  3.917606 -1.277955 -1.949397   0.000000    3.8067
# 1      1961-06-15  3.978498 -1.257404 -2.247617   0.000000    3.8694
# 2      1961-06-16  3.984350 -1.429538 -1.885024   0.000000    3.8634
# 3      1961-06-19  4.004379 -0.723311 -3.310743   0.000000    3.9196
# 4      1961-06-20  3.985789 -0.900432 -2.844809   0.000000    3.8732
# ...           ...       ...       ...       ...        ...       ...
# 16813  2025-11-24  1.444998  2.444102  0.000021  11.042117    3.3901
# 16814  2025-11-25  1.307883  2.595236 -0.000028  11.447813    3.3510
# 16815  2025-11-26  1.261448  2.659221  0.000048  11.456580    3.3637
# 16816  2025-11-27       NaN       NaN       NaN        NaN       NaN
# 16817  2025-11-28  1.253482  2.660574  0.000090  11.541530    3.3906
#
#        SVEN1F04  SVEN1F09  SVENF01  SVENF02  ...  SVENY23  SVENY24  SVENY25  \
# ...
