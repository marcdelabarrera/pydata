# %%
from pydata.papers import shiller

# %%
from pydata.papers import gurkaynak

# %%
yield_curve = gurkaynak.yield_curve("2020-01-04")

# %%
yield_curve.plot()
# Out:
# <Axes: xlabel='t'>

# %%
gurkaynak.yield_curve("2020-01-01")
